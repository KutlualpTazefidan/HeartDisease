# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import featuretools as ft

# %%
df = pd.read_csv('./HeartDiseaseDataset/ImportedDataset.csv')
df = df.reset_index()
df.head()
# Out:
#    index   age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  \
# 0      0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0
# 1      1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0
# 2      2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0
# 3      3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0
# 4      4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0
#
#    oldpeak  slope   ca  thal  num
# 0      2.3    3.0  0.0   6.0    0
# 1      1.5    2.0  3.0   3.0    2
# 2      2.6    2.0  2.0   7.0    1
# 3      3.5    3.0  0.0   3.0    0
# 4      1.4    1.0  0.0   3.0    0

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Combining Features to improve ML

# %%
# Automatic Feature Engineering with FeatureTools
dataframes = {
    "heart_disease": (df,'index')
}
features = ft.dfs(dataframes=dataframes,target_dataframe_name="heart_disease",trans_primitives = ['add_numeric'])

# %%
print(features)
# Out:
# (        age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# index
# 0      63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1      67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2      67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3      37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4      41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ...     ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298    45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299    68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300    57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301    57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302    38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#        ...  sex + slope  sex + thal  sex + thalach  sex + trestbps  \
# index  ...
# 0      ...          4.0         7.0          151.0           146.0
# 1      ...          3.0         4.0          109.0           161.0
# 2      ...          3.0         8.0          130.0           121.0
# 3      ...          4.0         4.0          188.0           131.0
# 4      ...          1.0         3.0          172.0           130.0
# ...    ...          ...         ...            ...             ...
# 298    ...          3.0         8.0          133.0           111.0
# 299    ...          3.0         8.0          142.0           145.0
# 300    ...          3.0         8.0          116.0           131.0
# 301    ...          2.0         3.0          174.0           130.0
# 302    ...          2.0         4.0          174.0           139.0
#
#        slope + thal  slope + thalach  slope + trestbps  thal + thalach  \
# index
# 0               9.0            153.0             148.0           156.0
# 1               5.0            110.0             162.0           111.0
# 2               9.0            131.0             122.0           136.0
# 3               6.0            190.0             133.0           190.0
# 4               4.0            173.0             131.0           175.0
# ...             ...              ...               ...             ...
# 298             9.0            134.0             112.0           139.0
# 299             9.0            143.0             146.0           148.0
# 300             9.0            117.0             132.0           122.0
# 301             5.0            176.0             132.0           177.0
# 302             4.0            174.0             139.0           176.0
#
#        thal + trestbps  thalach + trestbps
# index
# 0                151.0               295.0
# 1                163.0               268.0
# 2                127.0               249.0
# 3                133.0               317.0
# 4                133.0               302.0
# ...                ...                 ...
# 298              117.0               242.0
# 299              151.0               285.0
# 300              137.0               245.0
# 301              133.0               304.0
# 302              141.0               311.0
#
# [303 rows x 105 columns], [<Feature: age>, <Feature: sex>, <Feature: cp>, <Feature: trestbps>, <Feature: chol>, <Feature: fbs>, <Feature: restecg>, <Feature: thalach>, <Feature: exang>, <Feature: oldpeak>, <Feature: slope>, <Feature: ca>, <Feature: thal>, <Feature: num>, <Feature: age + ca>, <Feature: age + chol>, <Feature: age + cp>, <Feature: age + exang>, <Feature: age + fbs>, <Feature: age + num>, <Feature: age + oldpeak>, <Feature: age + restecg>, <Feature: age + sex>, <Feature: age + slope>, <Feature: age + thal>, <Feature: age + thalach>, <Feature: age + trestbps>, <Feature: ca + chol>, <Feature: ca + cp>, <Feature: ca + exang>, <Feature: ca + fbs>, <Feature: ca + num>, <Feature: ca + oldpeak>, <Feature: ca + restecg>, <Feature: ca + sex>, <Feature: ca + slope>, <Feature: ca + thal>, <Feature: ca + thalach>, <Feature: ca + trestbps>, <Feature: chol + cp>, <Feature: chol + exang>, <Feature: chol + fbs>, <Feature: chol + num>, <Feature: chol + oldpeak>, <Feature: chol + restecg>, <Feature: chol + sex>, <Feature: chol + slope>, <Feature: chol + thal>, <Feature: chol + thalach>, <Feature: chol + trestbps>, <Feature: cp + exang>, <Feature: cp + fbs>, <Feature: cp + num>, <Feature: cp + oldpeak>, <Feature: cp + restecg>, <Feature: cp + sex>, <Feature: cp + slope>, <Feature: cp + thal>, <Feature: cp + thalach>, <Feature: cp + trestbps>, <Feature: exang + fbs>, <Feature: exang + num>, <Feature: exang + oldpeak>, <Feature: exang + restecg>, <Feature: exang + sex>, <Feature: exang + slope>, <Feature: exang + thal>, <Feature: exang + thalach>, <Feature: exang + trestbps>, <Feature: fbs + num>, <Feature: fbs + oldpeak>, <Feature: fbs + restecg>, <Feature: fbs + sex>, <Feature: fbs + slope>, <Feature: fbs + thal>, <Feature: fbs + thalach>, <Feature: fbs + trestbps>, <Feature: num + oldpeak>, <Feature: num + restecg>, <Feature: num + sex>, <Feature: num + slope>, <Feature: num + thal>, <Feature: num + thalach>, <Feature: num + trestbps>, <Feature: oldpeak + restecg>, <Feature: oldpeak + sex>, <Feature: oldpeak + slope>, <Feature: oldpeak + thal>, <Feature: oldpeak + thalach>, <Feature: oldpeak + trestbps>, <Feature: restecg + sex>, <Feature: restecg + slope>, <Feature: restecg + thal>, <Feature: restecg + thalach>, <Feature: restecg + trestbps>, <Feature: sex + slope>, <Feature: sex + thal>, <Feature: sex + thalach>, <Feature: sex + trestbps>, <Feature: slope + thal>, <Feature: slope + thalach>, <Feature: slope + trestbps>, <Feature: thal + thalach>, <Feature: thal + trestbps>, <Feature: thalach + trestbps>])

# %%
numerical_features = ['age','trestbps','chol','thalach','oldpeak']
categorical_features = ['sex','cp','fbs','thalach','restecg','exang','slope','ca','thal']
# Scaling numerical before combining them
scaler = StandardScaler()
df[[col + "_scaled" for col in numerical_features]] = scaler.fit_transform(df[numerical_features])

# %%
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca  thal  num  age_scaled  trestbps_scaled  chol_scaled  \
# 0      3.0  0.0   6.0    0    0.948726         0.757525    -0.264900
# 1      2.0  3.0   3.0    2    1.392002         1.611220     0.760415
# 2      2.0  2.0   7.0    1    1.392002        -0.665300    -0.342283
# 3      3.0  0.0   3.0    0   -1.932564        -0.096170     0.063974
# 4      1.0  0.0   3.0    0   -1.489288        -0.096170    -0.825922
# ..     ...  ...   ...  ...         ...              ...          ...
# 298    2.0  0.0   7.0    1   -1.046013        -1.234430     0.334813
# 299    2.0  2.0   7.0    2    1.502821         0.700612    -1.038723
# 300    2.0  1.0   7.0    3    0.283813        -0.096170    -2.238149
# 301    2.0  1.0   3.0    1    0.283813        -0.096170    -0.206864
# 302    1.0  0.0   3.0    0   -1.821745         0.359134    -1.386944
#
#      thalach_scaled  oldpeak_scaled
# 0          0.017197        1.087338
# 1         -1.821905        0.397182
# 2         -0.902354        1.346147
# 3          1.637359        2.122573
# 4          0.980537        0.310912
# ..              ...             ...
# 298       -0.770990        0.138373
# 299       -0.376896        2.036303
# 300       -1.515388        0.138373
# 301        1.068113       -0.896862
# 302        1.024325       -0.896862
#
# [303 rows x 19 columns]

# %%
scaled_values
# Out:
# array([[ 0.94872647,  0.75752504, -0.2649003 ,  0.01719733,  1.08733806],
#        [ 1.39200191,  1.61121989,  0.76041519, -1.82190531,  0.39718162],
#        [ 1.39200191, -0.6652997 , -0.34228261, -0.90235399,  1.34614673],
#        ...,
#        [ 0.28381332, -0.0961698 , -2.23814899, -1.51538821,  0.13837295],
#        [ 0.28381332, -0.0961698 , -0.20686358,  1.06811312, -0.89686172],
#        [-1.82174501,  0.35913411, -1.38694368,  1.02432497, -0.89686172]])

# %%
def combine_features():

# %%
df.columns[0]
# Out:
# 'age'

# %%
scaled_values
# Out:
# array([[ 0.94872647,  0.75752504, -0.2649003 ,  0.01719733,  1.08733806],
#        [ 1.39200191,  1.61121989,  0.76041519, -1.82190531,  0.39718162],
#        [ 1.39200191, -0.6652997 , -0.34228261, -0.90235399,  1.34614673],
#        ...,
#        [ 0.28381332, -0.0961698 , -2.23814899, -1.51538821,  0.13837295],
#        [ 0.28381332, -0.0961698 , -0.20686358,  1.06811312, -0.89686172],
#        [-1.82174501,  0.35913411, -1.38694368,  1.02432497, -0.89686172]])
